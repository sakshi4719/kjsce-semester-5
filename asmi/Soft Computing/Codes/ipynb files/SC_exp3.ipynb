# %%
import pandas as pd
import random

# %%
# Activation function
def activation(net, threshold):
  if net >= threshold:
    return 1
  else:
    return -1

# %%
# Perceptron Training Algorithm

def perceptron(input_vector):

    # Initial setup
    threshold = random.randrange(0,5)
    w1 = random.randrange(-2,3)
    w2 = random.randrange(-2,3)
    wb = random.randrange(-2,3)
    print("Threshold = {0}\n".format(threshold))
    print("Initial weights:\nw1 = {0}\tw2 = {1}\twb = {2}\n".format(w1, w2, wb))

    # Algorithm
    repeat = True
    result = [0, 0, 0, 0]
    firstRunWts = ()
    j = 0
    while repeat:
        j += 1
        print("Iteration {0}".format(j))
        i = 0
        firstIteration = True
        for input in input_vector:
            x1, x2 = input
            t = target[i]
            net = x1*w1 + x2*w2 + wb
            y = activation(net, threshold)
            result[i] = y
            if y != t:
                w1 = w1 + (t-y) * x1
                w2 = w2 + (t-y) * x2
                wb = wb + (t-y)
            i += 1
            if firstIteration == True:
                firstRunWts = (w1, w2, wb)
            firstIteration = False
            print("Weights after input ({0}, {1}):\tw1 = {2}\tw2 = {3}\twb = {4}".format(x1, x2, w1, w2, wb))
        print("Iteration complete.")
        print("Updated weights:\nw1 = {0}\tw2 = {1}\twb = {2}\n".format(w1, w2, wb))
        lastRunWts = (w1, w2, wb)
        if lastRunWts == firstRunWts or result == target:
            repeat = False
    print("Final weights:\nw1 = {0}\tw2 = {1}\twb = {2}\n".format(w1, w2, wb))
    return result

# %%
def displayLogic(input_vector, target, result):
    column_names = pd.DataFrame([["Input Vector", "x1"],
                                ["Input Vector", "x2"],
                                ["Target", "Output"],
                                ["Predicted", "Output"]],
                                columns=["", ""])

    rows = []
    for i, input in enumerate(input_vector):
        x1, x2 = input
        row = []
        row.extend([x1, x2, target[i], result[i]])
        rows.append(row)

    columns = pd.MultiIndex.from_frame(column_names)

    df = pd.DataFrame(rows, columns=columns)
    df = df.style.set_properties(**{'text-align': 'right'})
    display(df)
    return

# %%
# AND Gate
x_1 = [-1, -1, 1, 1]
x_2 = [-1, 1, -1, 1]
input_vector = list(zip(x_1, x_2))
target = [-1, -1, -1, 1]

result = perceptron(input_vector)
displayLogic(input_vector, target, result)
# Out:
# Threshold = 0
#
# Initial weights:
# w1 = -2	w2 = 2	wb = -1
#
# Iteration 1
# Weights after input (-1, -1):	w1 = -2	w2 = 2	wb = -1
# Weights after input (-1, 1):	w1 = 0	w2 = 0	wb = -3
# Weights after input (1, -1):	w1 = 0	w2 = 0	wb = -3
# Weights after input (1, 1):	w1 = 2	w2 = 2	wb = -1
# Iteration complete.
# Updated weights:
# w1 = 2	w2 = 2	wb = -1
#
# Iteration 2
# Weights after input (-1, -1):	w1 = 2	w2 = 2	wb = -1
# Weights after input (-1, 1):	w1 = 2	w2 = 2	wb = -1
# Weights after input (1, -1):	w1 = 2	w2 = 2	wb = -1
# Weights after input (1, 1):	w1 = 2	w2 = 2	wb = -1
# Iteration complete.
# Updated weights:
# w1 = 2	w2 = 2	wb = -1
#
# Final weights:
# w1 = 2	w2 = 2	wb = -1
# <style type="text/css">
# #T_12857_row0_col0, #T_12857_row0_col1, #T_12857_row0_col2, #T_12857_row0_col3, #T_12857_row1_col0, #T_12857_row1_col1, #T_12857_row1_col2, #T_12857_row1_col3, #T_12857_row2_col0, #T_12857_row2_col1, #T_12857_row2_col2, #T_12857_row2_col3, #T_12857_row3_col0, #T_12857_row3_col1, #T_12857_row3_col2, #T_12857_row3_col3 {
#   text-align: right;
# }
# </style>
# <table id="T_12857" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_12857_level0_col0" class="col_heading level0 col0" colspan="2">Input Vector</th>
#       <th id="T_12857_level0_col2" class="col_heading level0 col2" >Target</th>
#       <th id="T_12857_level0_col3" class="col_heading level0 col3" >Predicted</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_12857_level1_col0" class="col_heading level1 col0" >x1</th>
#       <th id="T_12857_level1_col1" class="col_heading level1 col1" >x2</th>
#       <th id="T_12857_level1_col2" class="col_heading level1 col2" >Output</th>
#       <th id="T_12857_level1_col3" class="col_heading level1 col3" >Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12857_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12857_row0_col0" class="data row0 col0" >-1</td>
#       <td id="T_12857_row0_col1" class="data row0 col1" >-1</td>
#       <td id="T_12857_row0_col2" class="data row0 col2" >-1</td>
#       <td id="T_12857_row0_col3" class="data row0 col3" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_12857_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12857_row1_col0" class="data row1 col0" >-1</td>
#       <td id="T_12857_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_12857_row1_col2" class="data row1 col2" >-1</td>
#       <td id="T_12857_row1_col3" class="data row1 col3" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_12857_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12857_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_12857_row2_col1" class="data row2 col1" >-1</td>
#       <td id="T_12857_row2_col2" class="data row2 col2" >-1</td>
#       <td id="T_12857_row2_col3" class="data row2 col3" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_12857_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12857_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_12857_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_12857_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_12857_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# OR Gate
x_1 = [-1, -1, 1, 1]
x_2 = [-1, 1, -1, 1]
input_vector = list(zip(x_1, x_2))
target = [-1, 1, 1, 1]

result = perceptron(input_vector)
displayLogic(input_vector, target, result)
# Out:
# Threshold = 3
#
# Initial weights:
# w1 = 1	w2 = 1	wb = -2
#
# Iteration 1
# Weights after input (-1, -1):	w1 = 1	w2 = 1	wb = -2
# Weights after input (-1, 1):	w1 = -1	w2 = 3	wb = 0
# Weights after input (1, -1):	w1 = 1	w2 = 1	wb = 2
# Weights after input (1, 1):	w1 = 1	w2 = 1	wb = 2
# Iteration complete.
# Updated weights:
# w1 = 1	w2 = 1	wb = 2
#
# Iteration 2
# Weights after input (-1, -1):	w1 = 1	w2 = 1	wb = 2
# Weights after input (-1, 1):	w1 = -1	w2 = 3	wb = 4
# Weights after input (1, -1):	w1 = 1	w2 = 1	wb = 6
# Weights after input (1, 1):	w1 = 1	w2 = 1	wb = 6
# Iteration complete.
# Updated weights:
# w1 = 1	w2 = 1	wb = 6
#
# Iteration 3
# Weights after input (-1, -1):	w1 = 3	w2 = 3	wb = 4
# Weights after input (-1, 1):	w1 = 3	w2 = 3	wb = 4
# Weights after input (1, -1):	w1 = 3	w2 = 3	wb = 4
# Weights after input (1, 1):	w1 = 3	w2 = 3	wb = 4
# Iteration complete.
# Updated weights:
# w1 = 3	w2 = 3	wb = 4
#
# Final weights:
# w1 = 3	w2 = 3	wb = 4
# <style type="text/css">
# #T_d16f0_row0_col0, #T_d16f0_row0_col1, #T_d16f0_row0_col2, #T_d16f0_row0_col3, #T_d16f0_row1_col0, #T_d16f0_row1_col1, #T_d16f0_row1_col2, #T_d16f0_row1_col3, #T_d16f0_row2_col0, #T_d16f0_row2_col1, #T_d16f0_row2_col2, #T_d16f0_row2_col3, #T_d16f0_row3_col0, #T_d16f0_row3_col1, #T_d16f0_row3_col2, #T_d16f0_row3_col3 {
#   text-align: right;
# }
# </style>
# <table id="T_d16f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_d16f0_level0_col0" class="col_heading level0 col0" colspan="2">Input Vector</th>
#       <th id="T_d16f0_level0_col2" class="col_heading level0 col2" >Target</th>
#       <th id="T_d16f0_level0_col3" class="col_heading level0 col3" >Predicted</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_d16f0_level1_col0" class="col_heading level1 col0" >x1</th>
#       <th id="T_d16f0_level1_col1" class="col_heading level1 col1" >x2</th>
#       <th id="T_d16f0_level1_col2" class="col_heading level1 col2" >Output</th>
#       <th id="T_d16f0_level1_col3" class="col_heading level1 col3" >Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d16f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d16f0_row0_col0" class="data row0 col0" >-1</td>
#       <td id="T_d16f0_row0_col1" class="data row0 col1" >-1</td>
#       <td id="T_d16f0_row0_col2" class="data row0 col2" >-1</td>
#       <td id="T_d16f0_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d16f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d16f0_row1_col0" class="data row1 col0" >-1</td>
#       <td id="T_d16f0_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_d16f0_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_d16f0_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d16f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d16f0_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_d16f0_row2_col1" class="data row2 col1" >-1</td>
#       <td id="T_d16f0_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_d16f0_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d16f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d16f0_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_d16f0_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_d16f0_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_d16f0_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# NOR Gate
x_1 = [-1, -1, 1, 1]
x_2 = [-1, 1, -1, 1]
input_vector = list(zip(x_1, x_2))
target = [1, -1, -1, -1]

result = perceptron(input_vector)
displayLogic(input_vector, target, result)
# Out:
# Threshold = 2
#
# Initial weights:
# w1 = 1	w2 = 0	wb = 1
#
# Iteration 1
# Weights after input (-1, -1):	w1 = -1	w2 = -2	wb = 3
# Weights after input (-1, 1):	w1 = 1	w2 = -4	wb = 1
# Weights after input (1, -1):	w1 = -1	w2 = -2	wb = -1
# Weights after input (1, 1):	w1 = -1	w2 = -2	wb = -1
# Iteration complete.
# Updated weights:
# w1 = -1	w2 = -2	wb = -1
#
# Iteration 2
# Weights after input (-1, -1):	w1 = -1	w2 = -2	wb = -1
# Weights after input (-1, 1):	w1 = -1	w2 = -2	wb = -1
# Weights after input (1, -1):	w1 = -1	w2 = -2	wb = -1
# Weights after input (1, 1):	w1 = -1	w2 = -2	wb = -1
# Iteration complete.
# Updated weights:
# w1 = -1	w2 = -2	wb = -1
#
# Final weights:
# w1 = -1	w2 = -2	wb = -1
# <style type="text/css">
# #T_17dfa_row0_col0, #T_17dfa_row0_col1, #T_17dfa_row0_col2, #T_17dfa_row0_col3, #T_17dfa_row1_col0, #T_17dfa_row1_col1, #T_17dfa_row1_col2, #T_17dfa_row1_col3, #T_17dfa_row2_col0, #T_17dfa_row2_col1, #T_17dfa_row2_col2, #T_17dfa_row2_col3, #T_17dfa_row3_col0, #T_17dfa_row3_col1, #T_17dfa_row3_col2, #T_17dfa_row3_col3 {
#   text-align: right;
# }
# </style>
# <table id="T_17dfa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_17dfa_level0_col0" class="col_heading level0 col0" colspan="2">Input Vector</th>
#       <th id="T_17dfa_level0_col2" class="col_heading level0 col2" >Target</th>
#       <th id="T_17dfa_level0_col3" class="col_heading level0 col3" >Predicted</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_17dfa_level1_col0" class="col_heading level1 col0" >x1</th>
#       <th id="T_17dfa_level1_col1" class="col_heading level1 col1" >x2</th>
#       <th id="T_17dfa_level1_col2" class="col_heading level1 col2" >Output</th>
#       <th id="T_17dfa_level1_col3" class="col_heading level1 col3" >Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17dfa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17dfa_row0_col0" class="data row0 col0" >-1</td>
#       <td id="T_17dfa_row0_col1" class="data row0 col1" >-1</td>
#       <td id="T_17dfa_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_17dfa_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_17dfa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_17dfa_row1_col0" class="data row1 col0" >-1</td>
#       <td id="T_17dfa_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_17dfa_row1_col2" class="data row1 col2" >-1</td>
#       <td id="T_17dfa_row1_col3" class="data row1 col3" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_17dfa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_17dfa_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_17dfa_row2_col1" class="data row2 col1" >-1</td>
#       <td id="T_17dfa_row2_col2" class="data row2 col2" >-1</td>
#       <td id="T_17dfa_row2_col3" class="data row2 col3" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_17dfa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_17dfa_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_17dfa_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_17dfa_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_17dfa_row3_col3" class="data row3 col3" >-1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# NAND Gate
x_1 = [-1, -1, 1, 1]
x_2 = [-1, 1, -1, 1]
input_vector = list(zip(x_1, x_2))
target = [1, 1, 1, -1]

result = perceptron(input_vector)
displayLogic(input_vector, target, result)
# Out:
# Threshold = 3
#
# Initial weights:
# w1 = -1	w2 = 0	wb = 1
#
# Iteration 1
# Weights after input (-1, -1):	w1 = -3	w2 = -2	wb = 3
# Weights after input (-1, 1):	w1 = -3	w2 = -2	wb = 3
# Weights after input (1, -1):	w1 = -1	w2 = -4	wb = 5
# Weights after input (1, 1):	w1 = -1	w2 = -4	wb = 5
# Iteration complete.
# Updated weights:
# w1 = -1	w2 = -4	wb = 5
#
# Iteration 2
# Weights after input (-1, -1):	w1 = -1	w2 = -4	wb = 5
# Weights after input (-1, 1):	w1 = -3	w2 = -2	wb = 7
# Weights after input (1, -1):	w1 = -3	w2 = -2	wb = 7
# Weights after input (1, 1):	w1 = -3	w2 = -2	wb = 7
# Iteration complete.
# Updated weights:
# w1 = -3	w2 = -2	wb = 7
#
# Iteration 3
# Weights after input (-1, -1):	w1 = -3	w2 = -2	wb = 7
# Weights after input (-1, 1):	w1 = -3	w2 = -2	wb = 7
# Weights after input (1, -1):	w1 = -3	w2 = -2	wb = 7
# Weights after input (1, 1):	w1 = -3	w2 = -2	wb = 7
# Iteration complete.
# Updated weights:
# w1 = -3	w2 = -2	wb = 7
#
# Final weights:
# w1 = -3	w2 = -2	wb = 7
# <style type="text/css">
# #T_2623f_row0_col0, #T_2623f_row0_col1, #T_2623f_row0_col2, #T_2623f_row0_col3, #T_2623f_row1_col0, #T_2623f_row1_col1, #T_2623f_row1_col2, #T_2623f_row1_col3, #T_2623f_row2_col0, #T_2623f_row2_col1, #T_2623f_row2_col2, #T_2623f_row2_col3, #T_2623f_row3_col0, #T_2623f_row3_col1, #T_2623f_row3_col2, #T_2623f_row3_col3 {
#   text-align: right;
# }
# </style>
# <table id="T_2623f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_2623f_level0_col0" class="col_heading level0 col0" colspan="2">Input Vector</th>
#       <th id="T_2623f_level0_col2" class="col_heading level0 col2" >Target</th>
#       <th id="T_2623f_level0_col3" class="col_heading level0 col3" >Predicted</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_2623f_level1_col0" class="col_heading level1 col0" >x1</th>
#       <th id="T_2623f_level1_col1" class="col_heading level1 col1" >x2</th>
#       <th id="T_2623f_level1_col2" class="col_heading level1 col2" >Output</th>
#       <th id="T_2623f_level1_col3" class="col_heading level1 col3" >Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2623f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2623f_row0_col0" class="data row0 col0" >-1</td>
#       <td id="T_2623f_row0_col1" class="data row0 col1" >-1</td>
#       <td id="T_2623f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_2623f_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2623f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2623f_row1_col0" class="data row1 col0" >-1</td>
#       <td id="T_2623f_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_2623f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_2623f_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2623f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2623f_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_2623f_row2_col1" class="data row2 col1" >-1</td>
#       <td id="T_2623f_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_2623f_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2623f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2623f_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_2623f_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_2623f_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_2623f_row3_col3" class="data row3 col3" >-1</td>
#     </tr>
#   </tbody>
# </table>
